# %% [markdown]
# Step 1: Install Required Libraries
# - !pip install psycopg2-binary
# - !pip install sentence-transformers
# - !pip install openai  # Only if you plan to use OpenAI's API

# %% [markdown]
# Step 2: Connect to PostgreSQL and Retrieve Data

# %%
import psycopg2
import pandas as pd

# Database connection details
db_config = {
    'host': 'localhost',
    'database': 'recipe_db',
    'user': 'postgres',
    'password': 'anckul7*K',
    'port': '5433'  
}

# Establish connection to PostgreSQL
conn = psycopg2.connect(**db_config)

# Retrieve recipes and ingredients data
query = """
SELECT r.name, r.description, n.calories, n.total_fat, n.protein, n.carbs, 
       i.ingredient_text, d.instruction_text
FROM recipes r
JOIN nutrition_facts n ON r.recipe_id = n.recipe_id
JOIN ingredients i ON r.recipe_id = i.recipe_id
JOIN directions d ON r.recipe_id = d.recipe_id;
"""

# Load data into a DataFrame
recipes_df = pd.read_sql(query, conn)
conn.close()

# Preview the retrieved data
print(recipes_df.head())
# Out:
# C:\Users\ancha\AppData\Local\Temp\ipykernel_22832\1466140673.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   recipes_df = pd.read_sql(query, conn)
#                                     name  \
# 0  Peanut Butter Banana Protein Smoothie
# 1  Peanut Butter Banana Protein Smoothie
# 2  Peanut Butter Banana Protein Smoothie
# 3  Peanut Butter Banana Protein Smoothie
# 4  Peanut Butter Banana Protein Smoothie
#
#                                          description  calories  total_fat  \
# 0  A nutritious and satisfying beverage for break...       482       8.34
# 1  A nutritious and satisfying beverage for break...       482       8.34
# 2  A nutritious and satisfying beverage for break...       482       8.34
# 3  A nutritious and satisfying beverage for break...       482       8.34
# 4  A nutritious and satisfying beverage for break...       482       8.34
#
#    protein  carbs              ingredient_text  \
# 0    28.57  77.97                        Honey
# 1    28.57  77.97                        Honey
# 2    28.57  77.97                        Honey
# 3    28.57  77.97  Oikos Triple Zero - Vanilla
# 4    28.57  77.97  Oikos Triple Zero - Vanilla
#
#                       instruction_text
# 0  Transfer to a tall glass and serve.
# 1     Add ice for desired consistency.
# 2      Mix all ingredients in blender.
# 3  Transfer to a tall glass and serve.
# 4     Add ice for desired consistency.

# %% [markdown]
# - The code successfully retrieved data from the PostgreSQL database, showing a sample output with five rows. Each row includes:
#
#     - name: Name of the recipe
#     - description: Description of the recipe
#     - calories, total_fat, protein, carbs: Nutritional information
#     - ingredient_text: Ingredients for the recipe
#     - instruction_text: Step-by-step instructions
# - The warning about using SQLAlchemy can be ignored here, as the query still succeeded.

# %% [markdown]
# Step 3: Data Preprocessing
# - Combine the recipe description, ingredients, and directions into a single text field for each recipe.

# %%
# Combine fields into a single text field for each recipe
recipes_df['text'] = recipes_df['description'] + " " + recipes_df['ingredient_text'] + " " + recipes_df['instruction_text']

# Group by recipe name to aggregate all ingredients and instructions per recipe
recipes_texts = recipes_df.groupby('name')['text'].apply(' '.join).reset_index()

# %% [markdown]
# Step 4: Generate Embeddings
# - Use a pre-trained model like Sentence Transformers to generate embeddings for each recipe.

# %%
from sentence_transformers import SentenceTransformer

# Load the pre-trained model
model = SentenceTransformer('all-MiniLM-L6-v2')  # You can choose other models if preferred

# Generate embeddings for each recipe text
recipes_texts['embedding'] = recipes_texts['text'].apply(lambda x: model.encode(x))

# %% [markdown]
# - The model, sentence-transformers/all-MiniLM-L6-v2, was successfully loaded, but with a warning related to caching limitations on Windows. This warning indicates that caching files might use more disk space if symbolic links are not supported, which is generally a minor concern unless disk space is limited.

# %% [markdown]
# Step 5: Save Embeddings to Database
# - If you want to save these embeddings back to the database for faster retrieval, you'll need to serialize them. Here’s an example using PostgreSQL.

# %%
import numpy as np
from sqlalchemy import create_engine

# Establish connection using SQLAlchemy for easier writing back
engine = create_engine(f"postgresql://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config.get('port', 5433)}/{db_config['database']}")

# Serialize embeddings as binary data
recipes_texts['embedding'] = recipes_texts['embedding'].apply(lambda x: np.array(x).tobytes())

# Save to a new table (or update an existing one)
recipes_texts[['name', 'embedding']].to_sql('recipe_embeddings', engine, if_exists='replace', index=False)
# Out:
# 566

# %% [markdown]
# The output 566 indicates that embeddings were generated for 566 recipes in the dataset.

# %% [markdown]
# Step 6: Build a Simple Recommendation Function
# - Calculate similarity scores between the user’s input and each recipe based on the embeddings.

# %%
from sklearn.metrics.pairwise import cosine_similarity

def recommend_recipes(user_input, recipes_texts, model, top_n=5):
    # Generate embedding for user input
    user_embedding = model.encode(user_input)

    # Calculate similarity scores
    recipes_texts['similarity'] = recipes_texts['embedding'].apply(
        lambda x: cosine_similarity([user_embedding], [np.frombuffer(x, dtype=np.float32)]).flatten()[0]
    )

    # Sort by similarity and return top N recommendations
    recommendations = recipes_texts.sort_values(by='similarity', ascending=False).head(top_n)
    return recommendations[['name', 'similarity']]

# Example usage
user_input = "high protein low carb breakfast"
recommendations = recommend_recipes(user_input, recipes_texts, model)
print(recommendations)
# Out:
#                                            name  similarity
# 1626  Ham Cheddar and Jalapeno Crustless Quiche    0.668146
# 1794                               Keto Waffles    0.647531
# 1132                       Cream Cheese Biscuit    0.627648
# 3343                   Vanilla Protein Pancakes    0.613065
# 299                 Banana Stuffed French Toast    0.611616

# %% [markdown]
# - The code provided recommendations based on the similarity of the recipes to a given user input ("high protein low carb breakfast"). The top 5 recommended recipes are:
#
#     - Ham Cheddar and Jalapeno Crustless Quiche - Similarity: 0.668146
#     - Cream Cheese Biscuit - Similarity: 0.627648
#     - Vanilla Protein Pancakes - Similarity: 0.613065
#     - Banana Stuffed French Toast - Similarity: 0.611616
#     - Strawberry Banana Protein Smoothie - Similarity: 0.598489
# - Each recipe in the recommendation list has a similarity score, indicating how closely it matches the user’s input based on the embeddings generated.

# %% [markdown]
# Explanation of Each Step
# - Data Retrieval: We connect to the database, query the necessary fields, and load the data into a Pandas DataFrame.
# - Preprocessing: Combine descriptions, ingredients, and directions for each recipe to create a unified text field, which improves the quality of embeddings.
# - Generate Embeddings: Use sentence-transformers to encode the text data into numerical vectors. These embeddings allow for similarity calculations.
# Save Embeddings (Optional): Save embeddings back to the database, serialized as binary data. This is optional but useful for faster future access.
# - Recommendation Function: Calculate cosine similarity between the user’s input embedding and each recipe's embedding to find the most relevant recipes.
# Notes
# - Embeddings Storage: If you plan to use embeddings frequently, storing them back in the database can be efficient, though it requires serialization.
# - Model Choice: You can experiment with different Sentence Transformers models or use OpenAI's API if preferred (note that OpenAI usage incurs costs).

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine, text
from sentence_transformers import SentenceTransformer

# Database configuration
db_config = {
    'host': 'localhost',
    'port': '5433',
    'database': 'recipe_db',
    'user': 'postgres',
    'password': 'anckul7*K'
}

# Initialize the embedding model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Establish connection using SQLAlchemy for easier database operations
engine = create_engine(f"postgresql://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['database']}")

# Enable SQLAlchemy logging (optional, useful for debugging)
import logging
logging.basicConfig()
logging.getLogger('sqlalchemy.engine').setLevel(logging.INFO)

# Step 1: Retrieve the data from the `recipes` table
query = """
SELECT recipe_id, name, description
FROM recipes;
"""
recipes_df = pd.read_sql(query, engine)

# Step 2: Generate embeddings for each recipe using SentenceTransformer
recipes_df['recipe_vector'] = recipes_df['description'].apply(lambda x: model.encode(x).tolist() if pd.notnull(x) else None)

# Step 3: Save the embeddings back to the database
with engine.connect() as conn:
    with conn.begin():  # Ensures that the transaction is committed or rolled back properly
        for idx, row in recipes_df.iterrows():
            if row['recipe_vector'] is not None:
                # Convert the embedding to a Python list, which is compatible with PostgreSQL double precision[]
                vector = row['recipe_vector']

                # Use a text query to avoid SQLAlchemy's automatic parameter conversion
                query = text("""
                    UPDATE recipes
                    SET recipe_vector = :vector
                    WHERE recipe_id = :recipe_id
                """)

                # Execute the query with named parameters, passing `vector` as a list
                conn.execute(query, {"vector": vector, "recipe_id": row['recipe_id']})

print("Embeddings have been successfully stored in the database.")
# Out:
# INFO:sqlalchemy.engine.Engine:select pg_catalog.version()
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:select current_schema()
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:show standard_conforming_strings
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# INFO:sqlalchemy.engine.Engine:[generated in 0.00051s] {'table_name': '\nSELECT recipe_id, name, description\nFROM recipes;\n', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# INFO:sqlalchemy.engine.Engine:
# SELECT recipe_id, name, description
# FROM recipes;
#
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[generated in 0.00045s] {'vector': [-0.07252924144268036, -0.005818681325763464, 0.02691289782524109, 0.03539087995886803, -0.034687913954257965, -0.015206246636807919, 0.04321315139532 ... (8135 characters truncated) ... 17448317259550095, 0.029346758499741554, 0.013299894519150257, -0.027725065127015114, 0.06553612649440765, 0.004788470920175314, 0.002202788833528757], 'recipe_id': 1262}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.004313s ago] {'vector': [-0.02263646572828293, -0.008084145374596119, -0.019366970285773277, 0.08414763957262039, -0.07106605172157288, -0.0014752056449651718, 0.078509315848 ... (8094 characters truncated) ... 28124619275331497, 0.010544291697442532, 0.024857046082615852, 0.007142950315028429, 0.03364085033535957, 0.009780972264707088, -0.006746320519596338], 'recipe_id': 1264}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.006198s ago] {'vector': [-0.025724822655320168, -0.0048021660186350346, -0.009089748375117779, 0.0918087288737297, 0.043413739651441574, 0.032189033925533295, -0.062689960002 ... (8149 characters truncated) ... 0.027836574241518974, 0.0509323813021183, 0.020556753501296043, -0.06886394321918488, -0.02178283780813217, 0.016563331708312035, 0.11968962103128433], 'recipe_id': 1266}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.007934s ago] {'vector': [-0.07548659294843674, -0.04206634312868118, -0.021330853924155235, 0.08003242313861847, -0.051864784210920334, 0.024695545434951782, 0.00681704236194 ... (8160 characters truncated) ... 009670224040746689, -0.019122034311294556, 0.01360060553997755, -0.024630220606923103, 0.11809507012367249, 0.08329940587282181, 0.018553484231233597], 'recipe_id': 1268}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.01024s ago] {'vector': [-0.03278259187936783, -0.02118540368974209, -0.05221075192093849, -0.0144072650000453, -0.03857748582959175, 0.03497866168618202, -0.0802939832210540 ... (8134 characters truncated) ... 5467812530696392, 0.005604385863989592, 0.0395168736577034, -0.04880068451166153, -0.048697371035814285, -0.007838957943022251, -0.061223506927490234], 'recipe_id': 1270}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.01204s ago] {'vector': [-0.07785830646753311, 0.030323831364512444, -0.025243869051337242, -0.0011222278699278831, -0.09155672043561935, -0.02756338380277157, -0.09310512989 ... (8126 characters truncated) ... 18, -0.07644541561603546, 0.0850752517580986, 0.04070087894797325, 0.06973699480295181, 0.05463114380836487, -0.04067015275359154, 0.0809706598520279], 'recipe_id': 1272}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.01393s ago] {'vector': [-0.030884960666298866, -0.025811195373535156, -0.011244410648941994, 0.06892784684896469, -0.13781388103961945, 0.009990571066737175, 0.0399921461939 ... (8146 characters truncated) ... .06922861933708191, 0.0562017597258091, 0.005621460732072592, -0.009384089149534702, 0.10177583992481232, 0.03775395452976227, -0.0069091543555259705], 'recipe_id': 1274}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.01627s ago] {'vector': [-0.10608986020088196, -0.07011192291975021, 0.050528571009635925, 0.009618446230888367, -0.05651401728391647, 0.03855210542678833, -0.048143453896045 ... (8152 characters truncated) ... 706423744559288, -0.01186509057879448, -0.001913536456413567, -0.037751175463199615, -0.021746762096881866, 0.07582943886518478, 0.005731108598411083], 'recipe_id': 1276}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.01812s ago] {'vector': [-0.04516691714525223, 0.010162653401494026, -0.007203404791653156, 0.07438896596431732, -0.12905831634998322, -0.017580533400177956, 0.01510216295719 ... (8136 characters truncated) ... .03733198717236519, -0.04860071837902069, -0.04288041591644287, 0.10844789445400238, 0.05673127993941307, -0.004020498134195805, -0.03702734038233757], 'recipe_id': 1278}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.02s ago] {'vector': [0.002249853452667594, -0.01261753961443901, 0.024768266826868057, 0.050928592681884766, 0.00084356137085706, 0.0413418784737587, 0.049166109412908554 ... (8108 characters truncated) ... 894632562994957, -0.024335678666830063, 0.0992438867688179, -0.04625735059380531, -0.0028550755232572556, 0.023751914501190186, -0.006495417095720768], 'recipe_id': 1280}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.02201s ago] {'vector': [-0.06741507351398468, 0.0065409461967647076, -0.02337713912129402, 0.03366194665431976, -0.052820947021245956, -0.044352348893880844, 0.0925192087888 ... (8130 characters truncated) ... .01803554594516754, 0.041241928935050964, -0.040493886917829514, 0.05936792492866516, 0.014905882067978382, 0.011987301521003246, -0.0050472691655159], 'recipe_id': 1282}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.02383s ago] {'vector': [-0.001979928696528077, -0.026989605277776718, 0.08704681694507599, 0.020427308976650238, 0.017945855855941772, -0.006161498837172985, 0.0702630728483 ... (8122 characters truncated) ... 0830067098140717, 0.054678820073604584, -0.04139888286590576, -0.012944799847900867, 0.013740194961428642, 0.058611609041690826, -0.06186067312955856], 'recipe_id': 1284}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.02548s ago] {'vector': [-0.01674739643931389, 0.04439009726047516, -0.021542878821492195, 0.03158510476350784, -0.09598408639431, -0.009101788513362408, 0.020028142258524895 ... (8135 characters truncated) ... -0.02753995731472969, 0.043036025017499924, 0.019546018913388252, 0.07407531142234802, 0.0621422715485096, -0.03802913427352905, 0.032363031059503555], 'recipe_id': 1286}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.02725s ago] {'vector': [-0.03178417682647705, 0.030225669965147972, -0.002671529771760106, 0.07918518781661987, -0.025396091863512993, -0.007278107572346926, -0.027083976194 ... (8138 characters truncated) ... .025389177724719048, 0.056809764355421066, 0.016527047380805016, -0.048116862773895264, 0.07837853580713272, -0.1405455321073532, 0.04286089912056923], 'recipe_id': 1288}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.029s ago] {'vector': [-0.03217785060405731, -0.03729396313428879, 0.02432434819638729, 0.06076844409108162, -0.015467749908566475, 0.017791397869586945, 0.0452338680624961 ... (8143 characters truncated) ... 91952604055405, -0.03528878465294838, -0.03933095932006836, -0.14198218286037445, -0.023681586608290672, 0.035623595118522644, 0.00028499416657723486], 'recipe_id': 1290}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.03077s ago] {'vector': [-0.01354495994746685, 0.09364110976457596, 0.06675399839878082, 0.07235962897539139, -0.10593244433403015, -0.0384068563580513, 0.08271872997283936,  ... (8096 characters truncated) ... 0.026767214760184288, 0.11948315799236298, -0.06624135375022888, 0.03756237402558327, 0.07000631093978882, 0.07198856770992279, -0.022641414776444435], 'recipe_id': 1292}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.03257s ago] {'vector': [-0.10998412221670151, -0.015376472845673561, 0.0005393701721914113, 0.0484808012843132, -0.04905330017209053, 0.0020036594942212105, 0.04053320735692 ... (8146 characters truncated) ... 3777585476636887, -0.006434631533920765, 0.031361762434244156, -0.014275344088673592, 0.08326929062604904, -0.004943390376865864, 0.10512948036193848], 'recipe_id': 1294}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.03443s ago] {'vector': [-0.08238457888364792, -0.01291340310126543, -0.02587040513753891, 0.08062859624624252, -0.03329157084226608, -0.011786789633333683, -0.04133748635649 ... (8142 characters truncated) ...  0.014171347953379154, -0.010053165256977081, 0.05567650869488716, -0.08077986538410187, 0.0789831280708313, 0.07140275090932846, 0.07971657067537308], 'recipe_id': 1296}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.0363s ago] {'vector': [-0.0685536339879036, -0.013585152104496956, -0.05422984063625336, 0.09054680168628693, -0.10138595104217529, -0.019063198938965797, -0.03718429058790 ... (8162 characters truncated) ... 70320281386375, -0.013260205276310444, -0.029880274087190628, -0.030535349622368813, 0.03388851881027222, -0.011315617710351944, 0.057302381843328476], 'recipe_id': 1298}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.03818s ago] {'vector': [-0.046164799481630325, -0.040858227759599686, -0.015117360278964043, 0.024713538587093353, -0.057565294206142426, 0.010577547363936901, 0.01392502710 ... (8134 characters truncated) ... , -0.05238126590847969, 0.11909069865942001, -0.03756139054894447, 0.04300456494092941, 0.0877440869808197, 0.02446982078254223, -0.04374102130532265], 'recipe_id': 1300}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.04014s ago] {'vector': [-0.032276369631290436, 0.0014833953464403749, 0.030459094792604446, 0.04879792034626007, -0.023759229108691216, -0.02782168611884117, 0.0692632570862 ... (8134 characters truncated) ... .03297960385680199, -0.04723873734474182, -0.01971246674656868, -0.014272122643887997, 0.04993389919400215, 0.06188594177365303, 0.005423528142273426], 'recipe_id': 1301}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.04202s ago] {'vector': [-0.04074360430240631, -0.010489828884601593, -0.002310780342668295, 0.04420219361782074, -0.13790351152420044, -0.03105175867676735, -0.0034206397831 ... (8148 characters truncated) ... 002746578538790345, 0.07514416426420212, 0.006783279590308666, 0.047768156975507736, 0.02765428088605404, -0.026192642748355865, -0.02451344206929207], 'recipe_id': 1302}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.04386s ago] {'vector': [0.05540698394179344, 0.07094452530145645, 0.04376033693552017, 0.06418180465698242, -0.05443630740046501, -0.025244830176234245, 0.03913113474845886, ... (8136 characters truncated) ... 0.06493664532899857, 0.02648467756807804, 0.07183527201414108, 0.11579582840204239, -0.05610300600528717, 0.0020902252290397882, 0.013702142983675003], 'recipe_id': 1303}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.04584s ago] {'vector': [-0.04525427892804146, -0.08608738332986832, -0.02271190844476223, 0.03698671609163284, -0.029170840978622437, 0.025958247482776642, 0.050355579704046 ... (8118 characters truncated) ... .053711727261543274, -0.08974787592887878, 0.031505342572927475, 0.05881435051560402, -0.050690658390522, 0.011701035313308239, -0.057567987591028214], 'recipe_id': 1304}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.04752s ago] {'vector': [-0.062218789011240005, 0.11592767387628555, 0.0022361995652318, 0.018546801060438156, -0.14067554473876953, -0.018820181488990784, 0.0165466088801622 ... (8150 characters truncated) ... 0.006439125165343285, 0.09001832455396652, 0.050052136182785034, 0.0038427654653787613, 0.01003077533096075, 0.04516850411891937, 0.04472669959068298], 'recipe_id': 1305}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.04928s ago] {'vector': [-0.009313056245446205, -0.041905492544174194, -0.03844211623072624, 0.08785437792539597, -0.007918731309473515, 0.06294408440589905, 0.11015167087316 ... (8121 characters truncated) ... 3812209516763687, 0.004720279015600681, -0.008592034690082073, 0.0064008599147200584, 0.08599255979061127, -0.02931869775056839, 0.015245080925524235], 'recipe_id': 1306}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.05089s ago] {'vector': [0.005997414235025644, -0.06324369460344315, 0.06386426091194153, 0.09789812564849854, -0.0788668692111969, -0.0259324349462986, 0.004502086900174618, ... (8146 characters truncated) ... -0.038974564522504807, 0.03465457260608673, 0.045250773429870605, 0.1060924232006073, -0.04669145494699478, 0.0916338711977005, -0.002280347514897585], 'recipe_id': 1307}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.05271s ago] {'vector': [-0.1154598593711853, 0.04938359186053276, 0.06985394656658173, -0.04537487030029297, -0.09928706288337708, -0.014457308687269688, 0.08677784353494644 ... (8127 characters truncated) ... 411559984087944, 0.028275836259126663, -0.027790242806077003, 0.06321011483669281, -0.0047325678169727325, 0.04082377627491951, -0.016299819573760033], 'recipe_id': 1308}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.05493s ago] {'vector': [-0.04781421273946762, -0.014404650777578354, 0.05159598961472511, -0.037482187151908875, -0.09327169507741928, -0.03836306184530258, 0.08411253988742 ... (8117 characters truncated) ... 0.017507275566458702, 0.03914084658026695, -0.026859456673264503, 0.11204206198453903, 0.0481284074485302, 0.04094424843788147, -0.010731020011007786], 'recipe_id': 1309}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.05716s ago] {'vector': [-0.028956705704331398, -0.00590067682787776, -0.03634990379214287, 0.045111283659935, -0.059788778424263, 0.05257774889469147, -0.05749905854463577,  ... (8108 characters truncated) ... 6731431931257248, -0.017645299434661865, 0.006464042700827122, -0.0887547954916954, 0.006402360275387764, -0.01991596445441246, -0.020824231207370758], 'recipe_id': 1310}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.05939s ago] {'vector': [0.02004091441631317, -0.0314943790435791, 0.02354624681174755, 0.054307930171489716, -0.061225831508636475, 0.01919872872531414, 0.08613364398479462, ... (8164 characters truncated) ... 0185254514217377, 0.002261626999825239, 0.01818533055484295, 0.10771674662828445, -0.044953931123018265, 0.010327893309295177, -0.0027921986766159534], 'recipe_id': 1311}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.0612s ago] {'vector': [-0.08535537123680115, 0.011858565732836723, 0.012258448638021946, 0.04442408308386803, 0.0035280142910778522, -0.029366984963417053, 0.01622646674513 ... (8131 characters truncated) ...  -0.0284719355404377, -0.038990627974271774, 0.0148026617243886, -0.06487277895212173, 0.05552656576037407, 0.047472018748521805, 0.05679504945874214], 'recipe_id': 1312}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.06291s ago] {'vector': [0.023961083963513374, 0.009727942757308483, 0.03715088218450546, 0.05493355169892311, -0.07885067164897919, -0.018010050058364868, 0.0380655080080032 ... (8128 characters truncated) ... 5, -0.06735500693321228, 0.08986182510852814, -0.0368943028151989, 0.033760830760002136, 0.0538937933743, 0.05557374656200409, -0.0003223322855774313], 'recipe_id': 1313}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.0645s ago] {'vector': [-0.04250715672969818, 0.03203461319208145, 0.06585647910833359, -0.019295072183012962, -0.048092637211084366, -0.08200782537460327, 0.120350144803524 ... (8097 characters truncated) ... , -0.02219041995704174, 0.0390608012676239, -0.04606875404715538, 0.08384822309017181, 0.03562362492084503, 0.0648568645119667, -0.056616928428411484], 'recipe_id': 1314}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.06631s ago] {'vector': [-0.09946493804454803, 0.02761242538690567, -0.011000091210007668, 0.06723679602146149, -0.08089055866003036, -0.004034540615975857, -0.02056822925806 ... (8138 characters truncated) ... 242945186793804, -0.042527828365564346, -0.0005893527995795012, -0.05527551472187042, 0.057134468108415604, 0.018086617812514305, 0.03031482920050621], 'recipe_id': 1315}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.06823s ago] {'vector': [-0.0860966145992279, -0.07484458386898041, -0.03901229053735733, 0.10841123014688492, -0.08582133054733276, -0.039088550955057144, -0.022551219910383 ... (8127 characters truncated) ... .0359233021736145, 0.007505662739276886, -0.0060867504216730595, -0.06787379086017609, 0.08263831585645676, 0.001402908586896956, -0.0190800279378891], 'recipe_id': 1319}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.07041s ago] {'vector': [-0.07042191922664642, 0.08902973681688309, 0.0009400700218975544, 0.08652245998382568, -0.04889795929193497, 0.040094707161188126, 0.1126241683959961 ... (8141 characters truncated) ... .05956918001174927, -0.044507309794425964, -0.06553522497415543, 0.04456307366490364, 0.10167701542377472, 0.08661570399999619, -0.016513042151927948], 'recipe_id': 45}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.07274s ago] {'vector': [0.03175221011042595, 0.01315344963222742, 0.015451977029442787, 0.036435820162296295, -0.1045738160610199, -0.023740293458104134, 0.05968287959694862 ... (8093 characters truncated) ... .034388940781354904, 0.10538683086633682, 0.020418472588062286, 0.00834912434220314, -0.10349006950855255, 0.09666626900434494, -0.036356713622808456], 'recipe_id': 46}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.07477s ago] {'vector': [-0.07024069130420685, -0.007504420820623636, -0.0018657161854207516, 0.04768097400665283, -0.1266493797302246, 0.027041463181376457, 0.01383810676634 ... (8134 characters truncated) ... 0.04407105967402458, 0.07346508651971817, -0.009612904861569405, 0.005757797975093126, 0.09798863530158997, -0.01930394396185875, -0.0674440786242485], 'recipe_id': 47}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.07662s ago] {'vector': [0.020533503964543343, 0.06196487694978714, 0.009566745720803738, 0.10893288999795914, -0.07822313904762268, -0.013860825449228287, 0.0945528596639633 ... (8142 characters truncated) ... 044003602117300034, 0.09737487882375717, 0.022890683263540268, 0.03811516985297203, 0.06696745753288269, -0.0021207539830356836, -0.03543798252940178], 'recipe_id': 48}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.07864s ago] {'vector': [-0.0031392548698931932, -0.029579926282167435, -0.003172642085701227, 0.0901775062084198, -0.06692033261060715, -0.032973576337099075, 0.078611753880 ... (8159 characters truncated) ... 0.0727519616484642, 0.0805053785443306, 0.05330188199877739, 0.016192065551877022, 1.0826895504578715e-06, 0.06621968001127243, -0.020874084904789925], 'recipe_id': 49}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.08043s ago] {'vector': [-0.07422053813934326, 0.09090808033943176, 0.01805191859602928, 0.09431194514036179, -0.08177625387907028, 0.0522703118622303, 0.043471697717905045,  ... (8101 characters truncated) ... .03260192275047302, -0.01593734696507454, -0.026200568303465843, 0.021752409636974335, 0.011356761679053307, 0.02712414599955082, 0.02310136891901493], 'recipe_id': 50}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.08226s ago] {'vector': [-0.04604436084628105, 0.08260171860456467, -0.0006312421173788607, 0.08650175482034683, -0.11668164283037186, 0.012146011926233768, 0.049325961619615 ... (8128 characters truncated) ... .022408828139305115, 0.03126506879925728, -0.02335897646844387, 0.07140205055475235, 0.020115889608860016, 0.045595936477184296, -0.04752414673566818], 'recipe_id': 51}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.08402s ago] {'vector': [-0.013143547810614109, 0.04720691591501236, -0.017860446125268936, 0.013791528530418873, -0.15725234150886536, 0.009910138323903084, 0.03232602402567 ... (8115 characters truncated) ... 538163095712662, -0.013926287181675434, 0.016640467569231987, 0.050813816487789154, -0.09124426543712616, -0.008713880553841591, -0.05462931841611862], 'recipe_id': 52}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.08601s ago] {'vector': [-0.019794030115008354, -0.013549941591918468, 0.02162313647568226, 0.11965473741292953, -0.14112098515033722, -0.03040398098528385, 0.052417397499084 ... (8115 characters truncated) ... .07773590832948685, 0.05243942514061928, -0.009871930815279484, -0.0340578518807888, 0.09704604744911194, 0.11182867735624313, -0.0034199703950434923], 'recipe_id': 53}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.08833s ago] {'vector': [-0.07993317395448685, 0.06708693504333496, 0.010161668062210083, 0.03630830720067024, -0.17179973423480988, -0.0081576993688941, 0.07100993394851685, ... (8136 characters truncated) ... 21475112065672874, 0.08370815962553024, 0.008848718367516994, -0.044720929116010666, 0.10434267669916153, -0.01401267759501934, -0.004279444459825754], 'recipe_id': 54}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.09035s ago] {'vector': [0.00279107503592968, 0.013422497548162937, 0.03188345581293106, 0.06692959368228912, -0.04778224229812622, -0.02843766286969185, 0.070295050740242, - ... (8132 characters truncated) ... .09508266299962997, 0.04484052583575249, -0.03304566070437431, -0.026525070890784264, 0.07962308824062347, -0.051926881074905396, 0.06836024671792984], 'recipe_id': 55}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.09248s ago] {'vector': [0.011472020298242569, 0.021761545911431313, 0.0023214707616716623, 0.04113795980811119, -0.11548629403114319, 0.005437732674181461, 0.145478188991546 ... (8126 characters truncated) ... 09817124158143997, 0.04022596403956413, 0.018820080906152725, 0.006341676227748394, -0.004896528087556362, 0.051912225782871246, -0.09059271961450577], 'recipe_id': 56}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.09455s ago] {'vector': [-0.026850197464227676, 0.09452740848064423, 0.04547327756881714, 0.05261151120066643, -0.05480083078145981, 0.00486729433760047, -0.02423782646656036 ... (8125 characters truncated) ... 0.019443446770310402, 0.03017437271773815, 0.006019972264766693, 0.026767030358314514, 0.14356261491775513, 0.03206672891974449, -0.04413250833749771], 'recipe_id': 57}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.09657s ago] {'vector': [0.008131635375320911, 0.022903617471456528, -0.057614102959632874, 0.11108668148517609, -0.07808110117912292, 0.00228801928460598, 0.0231396984308958 ... (8109 characters truncated) ... 1926540695130825, 0.09460772573947906, 0.0060631087981164455, 0.01910536363720894, 0.020988240838050842, -0.053376905620098114, -0.001627675024792552], 'recipe_id': 58}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.09819s ago] {'vector': [-0.04838167130947113, 0.10836464166641235, -0.002707442734390497, 0.1169721707701683, -0.08241118490695953, 0.020479939877986908, 0.05134026333689689 ... (8166 characters truncated) ... 205376505851746, -0.04829048365354538, -0.04887555539608002, 0.05634896457195282, -0.00013004134234506637, -0.0317259281873703, -0.023828595876693726], 'recipe_id': 59}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.09989s ago] {'vector': [0.0005690385587513447, -0.017414528876543045, -0.06309973448514938, 0.042082685977220535, -0.07023550570011139, -0.002634420059621334, -0.02968917600 ... (8126 characters truncated) ... .09830879420042038, 0.07102519273757935, -0.04531726613640785, 0.004055442288517952, 0.046386510133743286, -0.047796349972486496, 0.01603063754737377], 'recipe_id': 60}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1021s ago] {'vector': [-0.08019734919071198, 0.026350539177656174, -0.04570680856704712, 0.04198345169425011, -0.0756964161992073, -0.015194602310657501, 0.0710692182183265 ... (8137 characters truncated) ... 0.028055114671587944, 0.0015690814470872283, 0.043118856847286224, 0.0791977122426033, -0.03847482055425644, 0.05609771981835365, 0.02781417779624462], 'recipe_id': 61}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1049s ago] {'vector': [-0.02019057795405388, 0.012018281035125256, 0.02456057071685791, 0.06689675897359848, -0.10155583918094635, 0.02893831394612789, 0.169514000415802, - ... (8124 characters truncated) ... 07906777411699295, 0.060105495154857635, -0.019405515864491463, 0.017760470509529114, -0.014926514588296413, 0.010144699364900589, -0.018919812515378], 'recipe_id': 62}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.107s ago] {'vector': [-0.0016041321214288473, -0.001007922226563096, 0.02876446023583412, 0.028170811012387276, -0.1019916757941246, 0.003881081473082304, -0.0134280957281 ... (8123 characters truncated) ... -0.017811397090554237, 0.07345187664031982, -0.05189617723226547, 0.09246162325143814, 0.06202803552150726, -0.07894065231084824, 0.05369473248720169], 'recipe_id': 63}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1088s ago] {'vector': [-0.010773788206279278, 0.06684156507253647, -0.004174746107310057, 0.05153495445847511, -0.10908740013837814, -0.018682150170207024, 0.02066984586417 ... (8118 characters truncated) ... 017043951898813248, 0.07956451922655106, 0.003323579905554652, -0.03386782854795456, 0.14044687151908875, -0.04556632041931152, -0.034067146480083466], 'recipe_id': 64}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1117s ago] {'vector': [-0.0755448043346405, 0.1104041263461113, 0.030933117493987083, 0.05713558942079544, -0.06378434598445892, 0.05182934179902077, -0.03621165081858635,  ... (8118 characters truncated) ... .04534139484167099, 0.029376469552516937, 0.013313989154994488, 0.007843758910894394, 0.09513095021247864, 0.06652433425188065, -0.003208866575732827], 'recipe_id': 65}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1136s ago] {'vector': [0.011991584673523903, -0.04568203166127205, 0.017033061012625694, 0.031238794326782227, -0.125527486205101, -0.0635465756058693, 0.024185115471482277 ... (8128 characters truncated) ... 050162333995103836, 0.016989052295684814, 0.019049420952796936, 0.017169704660773277, 0.05449744686484337, -0.03583010286092758, 0.017715811729431152], 'recipe_id': 66}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1153s ago] {'vector': [0.013153469190001488, 0.06267456710338593, -0.003583621233701706, 0.05604343116283417, -0.10998640954494476, -0.04050646722316742, 0.0965450629591941 ... (8126 characters truncated) ... 25765120983, -0.011945770122110844, -0.012470290996134281, 0.056249022483825684, -0.010526197031140327, -0.0060936822555959225, -0.027812201529741287], 'recipe_id': 67}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1171s ago] {'vector': [-0.00509313540533185, 0.12074980139732361, 0.04589671269059181, 0.08753950148820877, -0.1144651249051094, -0.022265076637268066, 0.03450419381260872, ... (8161 characters truncated) ... 021697411313652992, 0.006715415511280298, -0.06976646929979324, 0.012735921889543533, 0.07210002839565277, -0.0466889850795269, -0.038169488310813904], 'recipe_id': 68}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1193s ago] {'vector': [-0.05210890993475914, -0.02262241393327713, 0.024023886770009995, 0.033111345022916794, -0.06950756162405014, 0.002935870550572872, 0.099303252995014 ... (8119 characters truncated) ...  -0.06857852637767792, 0.010692867450416088, 0.01550457812845707, 0.025668207556009293, 0.028687143698334694, 0.0609147883951664, 0.03658110275864601], 'recipe_id': 69}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1219s ago] {'vector': [-0.02669513039290905, 0.11336327344179153, 0.033558208495378494, 0.10341291129589081, -0.03949069604277611, 0.01657080464065075, 0.02418086864054203, ... (8132 characters truncated) ... 29004210606217384, -0.039606329053640366, -0.03780650720000267, 0.03989364579319954, 0.021549033001065254, -0.03320927917957306, 0.007038895506411791], 'recipe_id': 70}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1241s ago] {'vector': [-0.02069065533578396, 0.05774468556046486, 0.02850760892033577, 0.02177763730287552, -0.04606835916638374, 0.0006008079508319497, 0.00833237823098898 ... (8119 characters truncated) ... -0.043854061514139175, 0.0230251494795084, -0.03474349156022072, -0.0516376793384552, 0.07853632420301437, -0.028465554118156433, 0.01151217333972454], 'recipe_id': 71}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1266s ago] {'vector': [-0.03858649730682373, 0.1010870710015297, -0.012614482082426548, 0.04250110685825348, -0.1310233324766159, -0.011484354734420776, 0.08326417952775955 ... (8154 characters truncated) ... 28015637770295143, 0.0023310447577387094, -0.0600467212498188, 0.037868522107601166, 0.01930055022239685, -0.005927659571170807, -0.04067913070321083], 'recipe_id': 72}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1297s ago] {'vector': [-0.019200697541236877, 0.06477771699428558, 0.02444983646273613, 0.08116757869720459, -0.06120697781443596, -0.02304588258266449, 0.08324059844017029 ... (8149 characters truncated) ... .07490986585617065, 0.0482977069914341, -0.05083408206701279, -0.07935427129268646, 0.0017327256500720978, 0.045982543379068375, -0.02724822238087654], 'recipe_id': 73}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1317s ago] {'vector': [-0.00669235922396183, 0.03549623861908913, -0.0006604362861253321, 0.030611688271164894, -0.1180122122168541, -0.003104663919657469, 0.15733890235424 ... (8149 characters truncated) ... .06386034935712814, 0.06943277269601822, -0.006671525537967682, -0.012042379938066006, 0.00199572229757905, 0.02598581276834011, -0.02694113552570343], 'recipe_id': 74}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1337s ago] {'vector': [0.017479104921221733, 0.06672614067792892, -0.045534905046224594, 0.03282955661416054, -0.060528434813022614, -0.0016546379774808884, 0.0986396446824 ... (8154 characters truncated) ... 790453102439642, 0.016435088589787483, -0.020782796666026115, -0.03993089497089386, -0.07320423424243927, -0.010049636475741863, 0.009371689520776272], 'recipe_id': 75}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1356s ago] {'vector': [-0.10439756512641907, 0.07125235348939896, 0.030350467190146446, 0.09784626215696335, -0.0648079514503479, 0.04978447034955025, 0.06809931248426437,  ... (8120 characters truncated) ... 36335717886686325, -0.027668075636029243, -0.010461249388754368, 0.021608559414744377, 0.07867692410945892, 0.02911870926618576, 0.008141802623867989], 'recipe_id': 76}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1387s ago] {'vector': [0.0005934842047281563, -0.0009360969415865839, -0.055862005800008774, 0.04452186077833176, -0.13556663691997528, 0.00041775908903218806, 0.0617660358 ... (8154 characters truncated) ... 624474257230759, -0.03740290179848671, -0.021362939849495888, 0.03566649928689003, 0.0012842186260968447, -0.021506989374756813, 0.038375161588191986], 'recipe_id': 77}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.141s ago] {'vector': [-0.08534731715917587, 0.07645180076360703, 0.0030728045385330915, 0.057828113436698914, -0.040775448083877563, 0.01850772835314274, 0.077752679586410 ... (8111 characters truncated) ... -0.022338464856147766, 0.04487724229693413, 0.05806261673569679, 0.0750463604927063, 0.05455363914370537, 0.038273319602012634, -0.000612047326285392], 'recipe_id': 78}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.144s ago] {'vector': [0.016972849145531654, 0.06093747913837433, 0.030349504202604294, 0.03033135086297989, -0.030265409499406815, 0.04779529199004173, -0.0010662303538993 ... (8130 characters truncated) ...  -0.0641019344329834, 0.012689314782619476, -0.05030464008450508, 0.007229370065033436, 0.06746300309896469, 0.095674067735672, -0.029520265758037567], 'recipe_id': 79}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.146s ago] {'vector': [0.006063442211598158, 0.06080657243728638, -0.0067841061390936375, 0.10149732232093811, -0.10955294221639633, -0.04975326731801033, 0.023199908435344 ... (8147 characters truncated) ... 006282361689954996, 0.0210425928235054, -0.012294339947402477, -0.028268607333302498, 0.07646632939577103, -0.08723344653844833, 0.022080419585108757], 'recipe_id': 80}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1491s ago] {'vector': [0.03173390030860901, 0.04257403314113617, 0.09303028136491776, 0.044399455189704895, 0.010043997317552567, 0.00994592159986496, 0.04624273627996445,  ... (8140 characters truncated) ... 653204694390297, -0.04158204793930054, 0.020437845960259438, -0.015823904424905777, 0.018981948494911194, 0.009293600916862488, 0.0013528078561648726], 'recipe_id': 81}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1508s ago] {'vector': [-0.07035756856203079, 0.04311210662126541, 0.06610957533121109, 0.10097304731607437, -0.09157679229974747, 0.06230580806732178, 0.11685101687908173,  ... (8157 characters truncated) ... 0980152115225792, 0.01577017456293106, -0.038544345647096634, 0.029890161007642746, 0.020947139710187912, 0.036132991313934326, -0.013605263084173203], 'recipe_id': 82}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1541s ago] {'vector': [-0.019526608288288116, -0.04760688915848732, 0.017234375700354576, -0.0007507080445066094, -0.12949375808238983, -0.039566706866025925, 0.08369462937 ... (8146 characters truncated) ... 07708758860826492, 0.021540241315960884, -0.041563935577869415, 0.0662817433476448, 0.028835756704211235, 0.012943259440362453, -0.009226192720234394], 'recipe_id': 83}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 0.1561s ago] {'vector': [-0.06708796322345734, 0.0021713869646191597, 0.02581961266696453, 0.030876675620675087, -0.05751524493098259, -0.048011403530836105, 0.08946844190359 ... (8131 characters truncated) ... 07854316383600235, 0.07588709145784378, 0.03220918029546738, -0.012545730918645859, -0.027878597378730774, 0.13544577360153198, -0.002709540305659175], 'recipe_id': 84}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# ...
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.26s ago] {'vector': [-0.07732905447483063, 0.022352397441864014, -0.05433813855051994, 0.07266758382320404, -0.13351835310459137, 0.0144801689311862, -0.00399632519111037 ... (8148 characters truncated) ... 0093220304697752, 0.0059017096646130085, 0.011597491800785065, 0.012639681808650494, 0.021352656185626984, -0.1295950710773468, -0.026146067306399345], 'recipe_id': 3585}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.27s ago] {'vector': [-0.03665990009903908, -0.011658604256808758, -0.029973343014717102, 0.0777537003159523, -0.02062932588160038, -0.0070373304188251495, -0.020477103069 ... (8115 characters truncated) ... 9788948595523834, -0.04594727233052254, -0.014059595763683319, -0.009408277459442616, -0.06322085857391357, -0.0719716027379036, 0.002965755295008421], 'recipe_id': 3586}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.27s ago] {'vector': [-0.07787422090768814, -0.06916516274213791, -0.027244195342063904, 0.06541167944669724, -0.0378471314907074, -0.0025393806863576174, 0.11713478714227 ... (8137 characters truncated) ...  -0.02197674661874771, 0.017416145652532578, 0.027111021801829338, -0.020806992426514626, 0.0765361413359642, 0.03438664600253105, 0.0238021370023489], 'recipe_id': 3587}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.27s ago] {'vector': [-0.024433106184005737, 0.013156197033822536, -0.03258209675550461, 0.07138171792030334, -0.01985022984445095, 0.02668098732829094, 0.1269546598196029 ... (8140 characters truncated) ... 02309398353099823, 0.06148363649845123, 0.026402246206998825, -0.05743533372879028, 0.00048432883340865374, 0.008435096591711044, 0.07366354018449783], 'recipe_id': 3588}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.28s ago] {'vector': [0.006513538770377636, 0.027744008228182793, 0.032570235431194305, 0.025163425132632256, 0.01276414655148983, -0.040511805564165115, 0.023572333157062 ... (8103 characters truncated) ... 11931379325687885, -0.06118785962462425, 0.03335646167397499, 0.029925119131803513, -0.055922552943229675, -0.03483942896127701, 0.034615546464920044], 'recipe_id': 3589}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.28s ago] {'vector': [-0.08302412927150726, 0.004802951123565435, 0.03841674327850342, 0.09333733469247818, -0.06946719437837601, -0.007579333148896694, -0.008501306176185 ... (8112 characters truncated) ... 775891676545143, -0.0014536351663991809, 0.0068129124119877815, 0.031946372240781784, 0.004859482403844595, 0.03587751090526581, 0.034542836248874664], 'recipe_id': 3590}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.28s ago] {'vector': [-0.09991080313920975, -0.08848387002944946, 0.03229745477437973, 0.004939937498420477, -0.006224420852959156, 0.03961522504687309, -0.005564199294894 ... (8142 characters truncated) ...  -0.058358386158943176, 0.04883705824613571, 0.03673972561955452, 0.08164060860872269, -0.049494419246912, 0.030719753354787827, -0.05337721109390259], 'recipe_id': 3591}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.29s ago] {'vector': [-0.14933016896247864, -0.0028441057074815035, 0.060159675776958466, 0.10323449224233627, -0.019411901012063026, 0.009123964235186577, -0.007832975126 ... (8121 characters truncated) ... .014430362731218338, -0.0018214760348200798, 0.04241621866822243, 0.04471365734934807, 0.05755392834544182, -0.06854546815156937, 0.04692116752266884], 'recipe_id': 3592}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.29s ago] {'vector': [-0.0945325717329979, 0.03817767649888992, -0.05223548412322998, 0.05200185626745224, -0.11252148449420929, 0.04231400415301323, 0.10438660532236099,  ... (8122 characters truncated) ... -0.06511956453323364, -0.007834777235984802, 0.04022705554962158, 0.0455351397395134, 0.017261020839214325, 0.004685470834374428, 0.03855576738715172], 'recipe_id': 3593}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.29s ago] {'vector': [-0.04815693572163582, 0.05306629091501236, -0.003889680840075016, 0.06276964396238327, 0.03903359919786453, -0.06539265066385269, -0.0248872134834527 ... (8115 characters truncated) ... 021402781829237938, 0.0376579686999321, 0.027089541777968407, -0.09924133121967316, 0.010788442566990852, -0.026311693713068962, 0.034914854913949966], 'recipe_id': 3594}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.29s ago] {'vector': [0.014827130362391472, -0.06932158023118973, -0.0002849035954568535, 0.004803525283932686, -0.035538818687200546, 0.02134285680949688, -0.088990136981 ... (8132 characters truncated) ... 1586924642324448, -0.005086927209049463, 0.017309125512838364, -0.05034420266747475, 0.0025409695226699114, 0.04120362922549248, -0.02255687676370144], 'recipe_id': 3595}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.3s ago] {'vector': [-0.0816185399889946, 0.04584477096796036, 0.016708752140402794, 0.020896483212709427, -0.14931218326091766, -0.03120497427880764, -0.0475787073373794 ... (8123 characters truncated) ... 08834931068122387, 0.017386294901371002, -0.004110203590244055, -0.049209319055080414, 0.09839377552270889, -0.02156057022511959, 0.02682105079293251], 'recipe_id': 3596}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.3s ago] {'vector': [-0.10267242044210434, -0.07094988226890564, -0.06263088434934616, 0.037721820175647736, -0.047587789595127106, 0.06529557704925537, -0.01821883209049 ... (8130 characters truncated) ... .06796731799840927, 0.04928850010037422, 0.013665714301168919, 0.03348224237561226, 0.002226070035248995, -0.07305537909269333, -0.040351878851652145], 'recipe_id': 3597}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.31s ago] {'vector': [-0.03392982482910156, 0.11183850467205048, 0.0084195202216506, 0.02532459981739521, -0.042638830840587616, 0.010780544020235538, 0.038564011454582214 ... (8166 characters truncated) ... .0002755707537289709, 0.07741446048021317, -0.02345576509833336, 0.06778998672962189, 0.0372825525701046, 0.025671493262052536, -0.006126014981418848], 'recipe_id': 3598}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.31s ago] {'vector': [-0.05064025893807411, 0.09166772663593292, 0.004615915007889271, 0.11061770468950272, -0.07516420632600784, -0.05542716756463051, 0.01839625276625156 ... (8112 characters truncated) ... , 0.0295253936201334, 0.055793650448322296, -0.01863863505423069, -0.016685178503394127, 0.01265906635671854, 0.09056144207715988, 0.0639752447605133], 'recipe_id': 3599}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.31s ago] {'vector': [-0.046359870582818985, 0.037611424922943115, -0.022712983191013336, 0.03572552651166916, -0.12935896217823029, 0.0450303740799427, -0.000436419097241 ... (8142 characters truncated) ...  -0.03847894072532654, 0.1371007263660431, 0.017131919041275978, 0.006677199155092239, 0.07729610800743103, -0.09552700072526932, 0.04344175010919571], 'recipe_id': 3600}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.32s ago] {'vector': [0.010471012443304062, -0.03465892747044563, 0.029721615836024284, 0.02377917803823948, 0.011255470104515553, -0.012598581612110138, -0.05830772221088 ... (8150 characters truncated) ... .009251212701201439, 0.04459762200713158, 0.010367690585553646, -0.06870857626199722, 0.07316739112138748, 0.007556039374321699, 0.008115091361105442], 'recipe_id': 3601}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.32s ago] {'vector': [-0.04047595337033272, -0.03263475000858307, -0.005073050502687693, 0.05477473884820938, -0.06577467918395996, 0.00932878628373146, 0.0254680551588535 ... (8139 characters truncated) ... 029352689161896706, 0.0017315279692411423, 0.007355418521910906, -0.07031360268592834, 0.06277622282505035, 0.019396411255002022, 0.03717688471078873], 'recipe_id': 3602}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.33s ago] {'vector': [-0.0568026639521122, -0.09297680854797363, -0.02554377168416977, 0.0174713134765625, -0.03372011333703995, 0.033777859061956406, 0.10036338865756989, ... (8113 characters truncated) ... 0.06488731503486633, 0.07709743827581406, -0.008677812293171883, 0.02983088046312332, 0.004813441541045904, -0.06034015491604805, -0.0190589502453804], 'recipe_id': 3603}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.33s ago] {'vector': [0.004363030660897493, 0.011776902712881565, -0.02772330306470394, 0.08877705782651901, -0.03047850914299488, -0.00822540558874607, 0.0712459981441497 ... (8142 characters truncated) ... 591456666588783, 0.06910435110330582, -0.0017771454295143485, -0.003408185439184308, -0.014408715069293976, 0.03506190702319145, -0.02268952876329422], 'recipe_id': 3604}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.34s ago] {'vector': [-0.08262735605239868, 0.00951338279992342, 0.008230892941355705, 0.03215773031115532, -0.17826803028583527, 0.029759839177131653, 0.0267128087580204, ... (8126 characters truncated) ... 0.05016385763883591, 0.05035972595214844, -0.024073569104075432, 0.08922559767961502, 0.031055500730872154, 0.010561148636043072, 0.02942541241645813], 'recipe_id': 3605}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.34s ago] {'vector': [-0.011138459667563438, 0.02243703417479992, -0.07206875830888748, 0.003945522475987673, -0.048946481198072433, -0.02312277816236019, -0.0737813487648 ... (8124 characters truncated) ... 29036961495876312, 0.021823422983288765, 0.017353646457195282, -0.07155376672744751, 0.004904717206954956, 0.04702143371105194, -0.010034525766968727], 'recipe_id': 3606}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.35s ago] {'vector': [-0.025686150416731834, -0.002989846281707287, 0.03758203238248825, 0.0763077661395073, -0.0640176460146904, 0.04429089277982712, 0.019976966083049774 ... (8127 characters truncated) ... 0.06420533359050751, 0.044679559767246246, 0.013207430951297283, 0.02895532362163067, 0.07674113661050797, 0.05475836247205734, -0.048888541758060455], 'recipe_id': 3607}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.35s ago] {'vector': [-0.06298018991947174, 0.06408724188804626, -0.03159895911812782, 0.13535194098949432, -0.05334431305527687, -0.023644743487238884, 0.0449974052608013 ... (8131 characters truncated) ...  0.03657474368810654, -0.0891801044344902, -0.03286667913198471, 0.020958686247467995, 0.01435855496674776, 0.004100267309695482, 0.03824980556964874], 'recipe_id': 3608}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.36s ago] {'vector': [-0.09222928434610367, 0.033893849700689316, 0.008065106347203255, 0.08612460643053055, -0.0729057565331459, -0.0328693613409996, 0.001874062931165099 ... (8109 characters truncated) ... 1546901911497116, -0.029990026727318764, 0.018363961949944496, -0.00731696467846632, 0.07898660749197006, 0.058432310819625854, 0.0004681725986301899], 'recipe_id': 3609}
# INFO:sqlalchemy.engine.Engine:
#                     UPDATE recipes
#                     SET recipe_vector = %(vector)s
#                     WHERE recipe_id = %(recipe_id)s
#
# INFO:sqlalchemy.engine.Engine:[cached since 12.36s ago] {'vector': [-0.06725332885980606, 0.016498379409313202, 0.0056079369969666, 0.06697347015142441, -0.07592111080884933, -0.014116956852376461, -0.0385636016726493 ... (8140 characters truncated) ...  -0.04461028426885605, 0.01656079851090908, 0.04743203893303871, -0.003478837199509144, 0.00895782746374607, 0.11666657030582428, 0.08233807981014252], 'recipe_id': 3610}
# INFO:sqlalchemy.engine.Engine:COMMIT
# Embeddings have been successfully stored in the database.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database configuration
db_config = {
    'host': 'localhost',
    'port': '5433',
    'database': 'recipe_db',
    'user': 'postgres',
    'password': 'anckul7*K'
}

# Establish connection using SQLAlchemy for easier database operations
engine = create_engine(f"postgresql://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['database']}")

# Step 1: Retrieve the data from the `recipes` table
query = """
SELECT recipe_id, name, description, servings, prep_time, cook_time, recipe_vector
FROM recipes;
"""
recipes_df = pd.read_sql(query, engine)

# Step 2: Convert the recipe_vector from array format to a string for saving to Excel
recipes_df['recipe_vector'] = recipes_df['recipe_vector'].apply(lambda x: ','.join(map(str, x)) if x is not None else '')

# Step 3: Save the data to an Excel file
output_file = 'recipes_with_vectors.xlsx'

# Create a Pandas Excel writer using XlsxWriter as the engine.
with pd.ExcelWriter(output_file, engine='xlsxwriter') as writer:
    recipes_df.to_excel(writer, sheet_name='Recipes', index=False)

print(f"Data has been successfully saved to {output_file}")
# Out:
# INFO:sqlalchemy.engine.Engine:select pg_catalog.version()
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:select current_schema()
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:show standard_conforming_strings
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# INFO:sqlalchemy.engine.Engine:[generated in 0.00217s] {'table_name': '\nSELECT recipe_id, name, description, servings, prep_time, cook_time, recipe_vector\nFROM recipes;\n', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# INFO:sqlalchemy.engine.Engine:
# SELECT recipe_id, name, description, servings, prep_time, cook_time, recipe_vector
# FROM recipes;
#
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# Data has been successfully saved to recipes_with_vectors.xlsx
